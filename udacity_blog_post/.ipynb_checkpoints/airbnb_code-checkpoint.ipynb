# %% [markdown]
# In order to get a better understanding of the data we will be looking at, let's take a look at some of the characteristics of the datasets.

# %%
# import libraries
import numpy as np
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import AllTogether as t

# %%
df_calendar = pd.read_csv('./calendar.csv')
df_listings = pd.read_csv('./listings.csv')
df_reviews = pd.read_csv('./reviews.csv')

# %%
df_calendar.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
df_listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
df_reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1393570 non-null  int64
#  1   date        1393570 non-null  object
#  2   available   1393570 non-null  object
#  3   price       934542 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 42.5+ MB

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84849 entries, 0 to 84848
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_id     84849 non-null  int64
#  1   id             84849 non-null  int64
#  2   date           84849 non-null  object
#  3   reviewer_id    84849 non-null  int64
#  4   reviewer_name  84849 non-null  object
#  5   comments       84831 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 3.9+ MB

# %% [markdown]
# We will try to solve the following questions:
#
# What are the ratings and prices of different locations in Seattle?
#
# How well can we predict a property's price? What aspects correlate well to price?
#
# How well can we predict a property's rating? What aspects correlate well to ratings?

# %% [markdown]
# First, I will analyze some columns related with location:

# %%
df_listings[["host_location", "host_neighbourhood", "neighbourhood", "neighbourhood_cleansed", "neighbourhood_group_cleansed"]]
# Out:
#                            host_location host_neighbourhood neighbourhood  \
# 0     Seattle, Washington, United States         Queen Anne    Queen Anne
# 1     Seattle, Washington, United States         Queen Anne    Queen Anne
# 2     Seattle, Washington, United States         Queen Anne    Queen Anne
# 3     Seattle, Washington, United States         Queen Anne    Queen Anne
# 4     Seattle, Washington, United States         Queen Anne    Queen Anne
# ...                                  ...                ...           ...
# 3813                                  US              Holly       Fremont
# 3814  Seattle, Washington, United States        Portage Bay   Portage Bay
# 3815                                  US                NaN           NaN
# 3816   Tacoma, Washington, United States                NaN           NaN
# 3817  Seattle, Washington, United States         Queen Anne    Queen Anne
#
#      neighbourhood_cleansed neighbourhood_group_cleansed
# ...

# %%
df_listings.neighbourhood_group_cleansed.value_counts()
# Out:
# Other neighborhoods    794
# Capitol Hill           567
# Downtown               530
# Central Area           369
# Queen Anne             295
# Ballard                230
# West Seattle           203
# Rainier Valley         159
# University District    122
# Beacon Hill            118
# Cascade                 89
# Northgate               80
# Delridge                79
# Lake City               67
# Magnolia                61
# Seward Park             44
# Interbay                11
# Name: neighbourhood_group_cleansed, dtype: int64

# %%
df_listings.neighbourhood_cleansed.value_counts()
# Out:
# Broadway             397
# Belltown             234
# Wallingford          167
# Fremont              158
# Minor                135
#                     ...
# Arbor Heights          5
# Pinehurst              4
# South Beacon Hill      4
# South Park             3
# Roxhill                2
# Name: neighbourhood_cleansed, Length: 87, dtype: int64

# %% [markdown]
# We will use the neighbourhood_group_cleansed, because it has less values, and it will be easier to visualize.

# %%
#Checking if the neighbourhood_group_cleansed column has null values
df_listings['neighbourhood_group_cleansed'].isnull().mean()
# Out:
# 0.0

# %%
#Checking if the price column has null values
df_listings['price'].isnull().mean()
# Out:
# 0.0

# %%
#Checking the columns with reviews

df_listings[["review_scores_rating", "review_scores_accuracy", "review_scores_cleanliness", "review_scores_checkin", "review_scores_communication", "review_scores_location", "review_scores_value"]]
# Out:
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                     95.0                    10.0                       10.0
# 1                     96.0                    10.0                       10.0
# 2                     97.0                    10.0                       10.0
# 3                      NaN                     NaN                        NaN
# 4                     92.0                     9.0                        9.0
# ...                    ...                     ...                        ...
# 3813                  80.0                     8.0                       10.0
# 3814                 100.0                    10.0                       10.0
# 3815                   NaN                     NaN                        NaN
# 3816                   NaN                     NaN                        NaN
# 3817                   NaN                     NaN                        NaN
#
# ...

# %%
#Checking if review_scores_rating has null values

df_listings['review_scores_rating'].isnull().mean()
# Out:
# 0.16946045049764275

# %%
df_listings.groupby(['neighbourhood_group_cleansed'])

# %%
df_listings['price']
# Out:
# 0        $85.00
# 1       $150.00
# 2       $975.00
# 3       $100.00
# 4       $450.00
#          ...
# 3813    $359.00
# 3814     $79.00
# 3815     $93.00
# 3816     $99.00
# 3817     $87.00
# Name: price, Length: 3818, dtype: object

# %%
df_listings['price'] = df_listings['price'].str.replace("$", "")
# Out:
# /var/folders/6w/mqsftc_d4ns8fl0kcnv5h9hh0000gn/T/ipykernel_21194/1548461865.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_listings['price'] = df_listings['price'].str.replace("$", "")

# %%
df_listings['price'] = df_listings['price'].str.replace(",", "")
df_listings['price'] = df_listings['price'].astype(float)

# %%
df_listings['price'].head()
# Out:
# 0     85.0
# 1    150.0
# 2    975.0
# 3    100.0
# 4    450.0
# Name: price, dtype: float64

# %%
df_listings.groupby(['neighbourhood_group_cleansed']).mean()['price'].sort_values(ascending=False)
# Out:
# /var/folders/6w/mqsftc_d4ns8fl0kcnv5h9hh0000gn/T/ipykernel_20479/1708466154.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_listings.groupby(['neighbourhood_group_cleansed']).mean()['price'].sort_values(ascending=False)
# neighbourhood_group_cleansed
# Magnolia               177.672131
# Queen Anne             157.223729
# Downtown               154.405660
# West Seattle           141.359606
# Cascade                140.101124
# Capitol Hill           130.592593
# Central Area           128.338753
# Ballard                124.682609
# Other neighborhoods    119.968514
# Interbay               109.727273
# Seward Park            108.477273
# Beacon Hill             94.669492
# University District     93.639344
# Lake City               92.671642
# Rainier Valley          91.899371
# ...

# %%
df_listings.groupby(['neighbourhood_group_cleansed']).mean()['review_scores_rating'].sort_values(ascending=False)
# Out:
# /var/folders/6w/mqsftc_d4ns8fl0kcnv5h9hh0000gn/T/ipykernel_20479/3851042129.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_listings.groupby(['neighbourhood_group_cleansed']).mean()['review_scores_rating'].sort_values(ascending=False)
# neighbourhood_group_cleansed
# Central Area           96.009404
# West Seattle           95.864198
# Delridge               95.861538
# Ballard                95.533679
# Queen Anne             95.443089
# Seward Park            95.025641
# Rainier Valley         94.731343
# Northgate              94.692308
# Other neighborhoods    94.562500
# Lake City              94.375000
# Capitol Hill           94.184783
# Beacon Hill            94.019417
# Downtown               93.958333
# Magnolia               93.787234
# Interbay               93.777778
# ...

# %%
base_color = sb.color_palette()[0]
sb.boxplot(data=df_listings, y='neighbourhood_group_cleansed', x='price', color=base_color);

# %%
neighborhood_price_medians = df_listings.groupby(['neighbourhood_group_cleansed']).median()['price'].sort_values(ascending=False)
neighborhood_price_medians
# Out:
# /var/folders/6w/mqsftc_d4ns8fl0kcnv5h9hh0000gn/T/ipykernel_20479/3948905961.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   neighborhood_price_medians = df_listings.groupby(['neighbourhood_group_cleansed']).median()['price'].sort_values(ascending=False)
# neighbourhood_group_cleansed
# Downtown               139.0
# Magnolia               129.0
# Queen Anne             119.0
# Cascade                115.0
# West Seattle           109.0
# Capitol Hill           105.0
# Central Area           100.0
# Other neighborhoods     99.0
# Ballard                 95.0
# Seward Park             93.0
# Interbay                90.0
# University District     85.0
# Rainier Valley          80.0
# Northgate               79.5
# Beacon Hill             75.0
# Delridge                72.0
# ...

# %%
neighborhood_price_means = df_listings.groupby(['neighbourhood_group_cleansed']).mean()['price'].sort_values(ascending=False)
neighborhood_price_means
# Out:
# /var/folders/6w/mqsftc_d4ns8fl0kcnv5h9hh0000gn/T/ipykernel_20479/3249324756.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   neighborhood_price_means = df_listings.groupby(['neighbourhood_group_cleansed']).mean()['price'].sort_values(ascending=False)
# neighbourhood_group_cleansed
# Magnolia               177.672131
# Queen Anne             157.223729
# Downtown               154.405660
# West Seattle           141.359606
# Cascade                140.101124
# Capitol Hill           130.592593
# Central Area           128.338753
# Ballard                124.682609
# Other neighborhoods    119.968514
# Interbay               109.727273
# Seward Park            108.477273
# Beacon Hill             94.669492
# University District     93.639344
# Lake City               92.671642
# ...

# %%
neighborhood_price_means_orders = df_listings.groupby(['neighbourhood_group_cleansed']).mean()['price'].sort_values(ascending=False).index
neighborhood_price_means_orders
# Out:
# /var/folders/6w/mqsftc_d4ns8fl0kcnv5h9hh0000gn/T/ipykernel_20479/2267717743.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   neighborhood_price_means_orders = df_listings.groupby(['neighbourhood_group_cleansed']).mean()['price'].sort_values(ascending=False).index
# Index(['Magnolia', 'Queen Anne', 'Downtown', 'West Seattle', 'Cascade',
#        'Capitol Hill', 'Central Area', 'Ballard', 'Other neighborhoods',
#        'Interbay', 'Seward Park', 'Beacon Hill', 'University District',
#        'Lake City', 'Rainier Valley', 'Northgate', 'Delridge'],
#       dtype='object', name='neighbourhood_group_cleansed')

# %%
sb.barplot(data = df_listings, x = 'price', y = 'neighbourhood_group_cleansed', color = base_color, order = neighborhood_price_means_orders)
# Out:
# <AxesSubplot:xlabel='price', ylabel='neighbourhood_group_cleansed'>

# %%
neighborhood_ratings_means = df_listings.groupby(['neighbourhood_group_cleansed']).mean()['review_scores_rating'].sort_values(ascending=False)
neighborhood_ratings_means
# Out:
# /var/folders/6w/mqsftc_d4ns8fl0kcnv5h9hh0000gn/T/ipykernel_20479/1599360023.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   neighborhood_ratings_means = df_listings.groupby(['neighbourhood_group_cleansed']).mean()['review_scores_rating'].sort_values(ascending=False)
# neighbourhood_group_cleansed
# Central Area           96.009404
# West Seattle           95.864198
# Delridge               95.861538
# Ballard                95.533679
# Queen Anne             95.443089
# Seward Park            95.025641
# Rainier Valley         94.731343
# Northgate              94.692308
# Other neighborhoods    94.562500
# Lake City              94.375000
# Capitol Hill           94.184783
# Beacon Hill            94.019417
# Downtown               93.958333
# Magnolia               93.787234
# ...

# %%
neighborhood_ratings_means_order = df_listings.groupby(['neighbourhood_group_cleansed']).mean()['review_scores_rating'].sort_values(ascending=False).index
neighborhood_ratings_means_order
# Out:
# /var/folders/6w/mqsftc_d4ns8fl0kcnv5h9hh0000gn/T/ipykernel_20479/3057261492.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   neighborhood_ratings_means_order = df_listings.groupby(['neighbourhood_group_cleansed']).mean()['review_scores_rating'].sort_values(ascending=False).index
# Index(['Central Area', 'West Seattle', 'Delridge', 'Ballard', 'Queen Anne',
#        'Seward Park', 'Rainier Valley', 'Northgate', 'Other neighborhoods',
#        'Lake City', 'Capitol Hill', 'Beacon Hill', 'Downtown', 'Magnolia',
#        'Interbay', 'Cascade', 'University District'],
#       dtype='object', name='neighbourhood_group_cleansed')

# %%
sb.barplot(data = df_listings, x = 'review_scores_rating', y = 'neighbourhood_group_cleansed', color = base_color, order = neighborhood_ratings_means_order)
plt.xlim((85,100));

# %%
X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test = t.clean_fit_linear_mod(df_listings, 'price')
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
#cutoffs here pertains to the number of missing values allowed in the used columns.
#Therefore, lower values for the cutoff provides more predictors in the model.
cutoffs = [5000, 3500, 2500, 1000, 100, 50]

r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
r2_scores_test
# Out:
# [0.4797574985551566,
#  0.5232861936852158,
#  -1.4455922734833088e+23,
#  -9.034951709470287e+21,
#  -3.0796492256785476e+16,
#  -4.541127560643022e+21]

# %%
X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test = t.clean_fit_linear_mod(df_listings, 'review_scores_rating')
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
#cutoffs here pertains to the number of missing values allowed in the used columns.
#Therefore, lower values for the cutoff provides more predictors in the model.
cutoffs = [5000, 3500, 2500, 1000, 100, 50]

r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
df_listings_modified = df_listings[["host_since", "host_response_time", "host_response_rate", "host_acceptance_rate", "neighbourhood_group_cleansed", "host_neighbourhood", "host_total_listings_count", "host_identity_verified","property_type","room_type","accommodates","bathrooms","bedrooms","beds","amenities","square_feet","price","security_deposit","minimum_nights","maximum_nights","has_availability","number_of_reviews","review_scores_rating","requires_license","instant_bookable","cancellation_policy","require_guest_profile_picture","require_guest_phone_verification","calculated_host_listings_count","reviews_per_month"]]

# %%
df_listings_modified
# Out:
#       host_since  host_response_time host_response_rate host_acceptance_rate  \
# 0     2011-08-11  within a few hours                96%                 100%
# 1     2013-02-21      within an hour                98%                 100%
# 2     2014-06-12  within a few hours                67%                 100%
# 3     2013-11-06                 NaN                NaN                  NaN
# 4     2011-11-29      within an hour               100%                  NaN
# ...          ...                 ...                ...                  ...
# 3813  2015-04-13  within a few hours                99%                 100%
# 3814  2015-10-14      within an hour               100%                 100%
# 3815  2015-12-30                 NaN                NaN                  NaN
# 3816  2015-01-03      within an hour               100%                  NaN
# 3817  2014-04-25        within a day               100%                  NaN
#
# ...

# %%
df_listings_modified = df_listings[["neighbourhood_group_cleansed","bathrooms","bedrooms","beds","square_feet","price","review_scores_rating"]]

# %%
df_listings_modified
# Out:
#      neighbourhood_group_cleansed  bathrooms  bedrooms  beds  square_feet  \
# 0                      Queen Anne        1.0       1.0   1.0          NaN
# 1                      Queen Anne        1.0       1.0   1.0          NaN
# 2                      Queen Anne        4.5       5.0   7.0          NaN
# 3                      Queen Anne        1.0       0.0   2.0          NaN
# 4                      Queen Anne        2.0       3.0   3.0          NaN
# ...                           ...        ...       ...   ...          ...
# 3813          Other neighborhoods        2.0       3.0   3.0          NaN
# 3814                 Capitol Hill        1.0       1.0   2.0          NaN
# 3815               Rainier Valley        1.0       1.0   1.0          NaN
# 3816                 Capitol Hill        1.0       0.0   1.0          NaN
# 3817                   Queen Anne        1.5       2.0   1.0          NaN
#
#       price  review_scores_rating
# 0      85.0                  95.0
# ...

# %%
cutoffs = [1000, 500, 250, 125, 60, 30]

# %%
X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test = t.clean_fit_linear_mod(df_listings_modified, 'price')
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
test_score
# Out:
# 0.5208551979750018

# %%
r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
r2_scores_test
# Out:
# [0.47224913128275836,
#  0.49562440939820773,
#  0.5079854798995739,
#  0.5110112496813407,
#  0.5202904898084402,
#  0.5208446995674159]

# %%
def coef_weights(coefficients, X_train):
    '''
    INPUT:
    coefficients - the coefficients of the linear model 
    X_train - the training data, so the column names can be used
    OUTPUT:
    coefs_df - a dataframe holding the coefficient, estimate, and abs(estimate)
    
    Provides a dataframe that can be used to understand the most influential coefficients
    in a linear model by providing the coefficient estimates along with the name of the 
    variable attached to the coefficient.
    '''
    coefs_df = pd.DataFrame()
    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs'] = coefficients
    coefs_df['abs_coefs'] = np.abs(lm_model.coef_)
    coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
    return coefs_df

#Use the function
coef_df = coef_weights(lm_model.coef_, X_train)

#A quick look at the top results
coef_df.head(20)
# Out:
#                                              est_int      coefs  abs_coefs
# 10             neighbourhood_group_cleansed_Downtown  51.951444  51.951444
# 7               neighbourhood_group_cleansed_Cascade  40.671769  40.671769
# 1                                           bedrooms  37.045167  37.045167
# 15           neighbourhood_group_cleansed_Queen Anne  36.117498  36.117498
# 12             neighbourhood_group_cleansed_Magnolia  35.186474  35.186474
# 0                                          bathrooms  28.031987  28.031987
# 13            neighbourhood_group_cleansed_Northgate -27.387804  27.387804
# 6          neighbourhood_group_cleansed_Capitol Hill  27.221258  27.221258
# 16       neighbourhood_group_cleansed_Rainier Valley -21.655742  21.655742
# 9              neighbourhood_group_cleansed_Delridge -19.276298  19.276298
# 2                                               beds  18.305972  18.305972
# ...

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
df_listings_modified_2 = df_listings[["host_response_time","host_response_rate","host_acceptance_rate","host_is_superhost","neighbourhood_group_cleansed","price","review_scores_rating"]]

# %%
X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test = t.clean_fit_linear_mod(df_listings_modified_2,'review_scores_rating')
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
test_score
# Out:
# -1.5414563827149996e+26

# %%
cutoffs = [1000, 500, 250, 125, 60, 30]

# %%
r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
#Use the function
coef_df = coef_weights(lm_model.coef_, X_train)

#A quick look at the top results
coef_df.head(20)
# Out:
#                                              est_int     coefs  abs_coefs
# 3                  host_response_time_within an hour  4.854974   4.854974
# 1                    host_response_time_within a day  4.774748   4.774748
# 2              host_response_time_within a few hours  3.573030   3.573030
# 8                                host_is_superhost_t  3.345329   3.345329
# 5                             host_response_rate_nan  2.504048   2.504048
# 4                             host_response_time_nan  2.504048   2.504048
# 10         neighbourhood_group_cleansed_Central Area  1.526679   1.526679
# 7                           host_acceptance_rate_nan -0.277669   0.277669
# 6                          host_acceptance_rate_100%  0.277669   0.277669
# 11             neighbourhood_group_cleansed_Downtown -0.259429   0.259429
# 12  neighbourhood_group_cleansed_Other neighborhoods  0.185009   0.185009
# 9          neighbourhood_group_cleansed_Capitol Hill -0.010223   0.010223
# ...

# %%
df_listings_modified_2 = df_listings[["host_response_time","host_response_rate","host_acceptance_rate","host_is_superhost","review_scores_rating"]]

# %%
X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test = t.clean_fit_linear_mod(df_listings_modified_2,'review_scores_rating')
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
test_score
# Out:
# -7.845592016483493e+22

# %%
r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test = t.clean_fit_linear_mod(df_listings,'review_scores_rating')
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
test_score
# Out:
# 0.21631298318354097

# %%
r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
#Use the function
coef_df = coef_weights(lm_model.coef_, X_train)

#A quick look at the top results
coef_df.head(20)
# Out:
#                                              est_int         coefs  \
# 1                                          scrape_id -6.521202e+14
# 34                                      city_Seattle -1.695946e+12
# 35                        smart_location_Seattle, WA  1.695946e+12
# 4                          host_total_listings_count -1.360710e+11
# 3                                host_listings_count  1.360710e+11
# 5                                           latitude -3.341794e+00
# 25                               review_scores_value  2.993612e+00
# 21                         review_scores_cleanliness  2.301893e+00
# 32                            host_has_profile_pic_t -1.983722e+00
# 20                            review_scores_accuracy  1.611318e+00
# 22                             review_scores_checkin  1.289549e+00
# 23                       review_scores_communication  1.242179e+00
# 33                          host_identity_verified_t  7.956668e-01
# ...

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
df_listings_modified_3 = df_listings[["scrape_id","city","smart_location","latitude","review_scores_rating","host_has_profile_pic"]]

# %%
X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test = t.clean_fit_linear_mod(df_listings_modified_3,'review_scores_rating')
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
test_score
# Out:
# -0.010796939398707517

# %%
r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
df_listings_modified_3 = df_listings[["host_total_listings_count","host_has_profile_pic","host_identity_verified","cancellation_policy","review_scores_rating","guests_included","host_acceptance_rate","bathrooms"]]

# %%
X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test = t.clean_fit_linear_mod(df_listings_modified_3,'review_scores_rating')
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
df_listings['host_response_rate'].head(50)
# Out:
# 0      96%
# 1      98%
# 2      67%
# 3      NaN
# 4     100%
# 5      NaN
# 6     100%
# 7     100%
# 8      NaN
# 9      98%
# 10    100%
# 11    100%
# 12    100%
# 13    100%
# 14    100%
# 15    100%
# 16    100%
# 17    100%
# 18     NaN
# 19     NaN
# 20    100%
# 21    100%
# 22    100%
# 23     NaN
# 24     NaN
# 25     67%
# 26    100%
# 27    100%
# 28    100%
# 29     71%
# 30     98%
# 31     97%
# 32     60%
# 33     71%
# 34    100%
# 35    100%
# 36     50%
# 37     31%
# 38    100%
# 39    100%
# 40    100%
# 41    100%
# 42     NaN
# 43    100%
# 44     50%
# 45     50%
# 46     90%
# 47    100%
# 48     NaN
# 49    100%
# Name: host_response_rate, dtype: object

# %%
df_listings['host_response_rate'] = df_listings['host_response_rate'].str.replace("%", "")
df_listings['host_response_rate'] = df_listings['host_response_rate'].astype(float)

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test = t.clean_fit_linear_mod(df_listings,'host_response_rate')
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
test_score
# Out:
# 0.19707699543387958

# %%
r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test = t.find_optimal_lm_mod(X, y, cutoffs)
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
#Use the function
coef_df = coef_weights(lm_model.coef_, X_train)

#A quick look at the top results
coef_df.head(20)
# Out:
#                                              est_int         coefs  \
# 1                                          scrape_id -3.235799e+14
# 36                        smart_location_Seattle, WA  3.152828e+12
# 35                                      city_Seattle -3.152828e+12
# 4                          host_total_listings_count  2.546289e+11
# 3                                host_listings_count -2.546289e+11
# 31                 host_response_time_within an hour  6.748575e+00
# 5                                           latitude  3.453959e+00
# 32                         host_acceptance_rate_100% -2.803904e+00
# 44                        cancellation_policy_strict  2.378198e+00
# 37                               is_location_exact_t  2.054616e+00
# 39                                 bed_type_Real Bed  1.903158e+00
# 43                      cancellation_policy_moderate  1.744988e+00
# 33                            host_has_profile_pic_t -1.694830e+00
# ...

# %%
df_listings_modified_3 = df_listings[["host_total_listings_count","host_has_profile_pic","host_identity_verified","cancellation_policy","review_scores_rating","guests_included","host_acceptance_rate","bathrooms",'host_response_rate']]

# %%
X, y, test_score, train_score, lm_model, X_train, X_test, y_train, y_test = t.clean_fit_linear_mod(df_listings_modified_3,'host_response_rate')
# Out:
# /Users/javierchapto/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
test_score
# Out:
# 0.034017019137316806

# %%
plt.scatter(data = df_listings, x = 'host_total_listings_count', y = 'host_response_rate', alpha = 1/8)
# plt.plot([10,60], [10,60]) # diagonal line from (10,10) to (60,60)
plt.xlabel('host_total_listings_count')
plt.ylabel('host_response_rate')
plt.xlim((0,50));

# %%
sb.heatmap(df_listings.corr(), annot = True, fmt = '.2f', cmap = 'vlag_r', center = 0)
# Out:
# /var/folders/6w/mqsftc_d4ns8fl0kcnv5h9hh0000gn/T/ipykernel_20479/2702947300.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(df_listings.corr(), annot = True, fmt = '.2f', cmap = 'vlag_r', center = 0)
# <AxesSubplot:>

# %%
num_vars = df_listings.select_dtypes(include=['float', 'int']).colu
num_vars.head(10)
# Out:
#         id       scrape_id   host_id  host_response_rate  host_listings_count  \
# 0   241032  20160104002432    956883                96.0                  3.0
# 1   953595  20160104002432   5177328                98.0                  6.0
# 2  3308979  20160104002432  16708587                67.0                  2.0
# 3  7421966  20160104002432   9851441                 NaN                  1.0
# 4   278830  20160104002432   1452570               100.0                  2.0
# 5  5956968  20160104002432    326758                 NaN                  1.0
# 6  1909058  20160104002432   2497928               100.0                  1.0
# 7   856550  20160104002432   4016632               100.0                  5.0
# 8  4948745  20160104002432   2166277                 NaN                  1.0
# 9  2493658  20160104002432   5177328                98.0                  6.0
#
#    host_total_listings_count   latitude   longitude  accommodates  bathrooms  \
# ...

# %%
sb.heatmap(num_vars.corr(), annot = True, fmt = '.2f', cmap = 'vlag_r', center = 0)
# Out:
# <AxesSubplot:>

# %%
num_vars = df_listings.select_dtypes(include=['float', 'int']).columns
num_vars
# Out:
# Index(['id', 'scrape_id', 'host_id', 'host_listings_count',
#        'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'square_feet', 'guests_included',
#        'minimum_nights', 'maximum_nights', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
df_listings_cor = df_listings[["host_response_rate", "host_listings_count", "accommodates", "bathrooms", "bedrooms", "square_feet", "availability_30", "number_of_reviews", "review_scores_rating", "price"]]

# %%
sb.heatmap(df_listings_cor.corr(), annot = True, fmt = '.2f', cmap = 'vlag_r', center = 0)
# Out:
# /var/folders/6w/mqsftc_d4ns8fl0kcnv5h9hh0000gn/T/ipykernel_21194/2815551223.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(df_listings_cor.corr(), annot = True, fmt = '.2f', cmap = 'vlag_r', center = 0)
# <AxesSubplot:>

# %%
df_listings
# Out:
#       host_response_rate  host_listings_count  accommodates  bathrooms  \
# 0                   96.0                  3.0             4        1.0
# 1                   98.0                  6.0             4        1.0
# 2                   67.0                  2.0            11        4.5
# 3                    NaN                  1.0             3        1.0
# 4                  100.0                  2.0             6        2.0
# ...                  ...                  ...           ...        ...
# 3813                99.0                354.0             6        2.0
# 3814               100.0                  1.0             4        1.0
# 3815                 NaN                  1.0             2        1.0
# 3816               100.0                  1.0             2        1.0
# 3817               100.0                  1.0             3        1.5
#
#       bedrooms  square_feet  availability_30  number_of_reviews  \
# ...

# %%
plt.scatter(data = df_listings, x = 'square_feet', y = 'review_scores_rating', alpha = 0.5)
# plt.plot([10,60], [10,60]) # diagonal line from (10,10) to (60,60)
plt.xlabel('square_feet')
plt.ylabel('review_scores_rating')
;
# Out:
# ''

# %%
plt.scatter(data = df_listings, x = 'square_feet', y = 'price', alpha = 0.5)
# plt.plot([10,60], [10,60]) # diagonal line from (10,10) to (60,60)
plt.xlabel('square_feet')
plt.ylabel('price')
;
# Out:
# ''

# %%
plt.scatter(data = df_listings, x = 'bedrooms', y = 'price', alpha = 0.5)
# plt.plot([10,60], [10,60]) # diagonal line from (10,10) to (60,60)
plt.xlabel('bedrooms')
plt.ylabel('price')
;
# Out:
# ''
